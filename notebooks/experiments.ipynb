# %% [markdown]
# ## Training

# %% [markdown]
# #### 0% paired dataset

# %%
# super_start is 0
# pour entraîner le modèle sur cpu seulement, ajouter --gpu_ids -1
# %run train.py --dataroot ./datasets/t12t2_brain/0 --model cycle_gan --dataset_mode unaligned --netG resnet_9blocks --direction AtoB --super_epochs 50 --super_epoch_start 0 --super_mode aligned --super_start 0 --name unpaired_gan --no_dropout

# %% [markdown]
# #### 25% paired dataset

# %%
# super_epochs increased
# %run train.py --dataroot ./datasets/t12t2_brain/0.25 --model cycle_gan --dataset_mode unaligned --netG resnet_9blocks --direction AtoB --super_epochs 100 --super_epoch_start 0 --super_mode aligned --super_start 1 --name paired_gan_25 --no_dropout

# %% [markdown]
# #### 50% paired dataset

# %%
# %run train.py --dataroot ./datasets/t12t2_brain/0.5 --model cycle_gan --dataset_mode unaligned --netG resnet_9blocks --direction AtoB --super_epochs 50 --super_epoch_start 0 --super_mode aligned --super_start 1 --name paired_gan_50 --no_dropout

# %% [markdown]
# #### 75% paired dataset

# %%
# %run train.py --dataroot ./datasets/t12t2_brain/0.75 --model cycle_gan --dataset_mode unaligned --netG resnet_9blocks --direction AtoB --super_epochs 50 --super_epoch_start 0 --super_mode aligned --super_start 1 --name paired_gan_75 --no_dropout

# %% [markdown]
# #### 100% paired dataset

# %%
# super_epochs and n_epochs are the same
# %run train.py --dataroot ./datasets/t12t2_brain/1 --model cycle_gan --dataset_mode unaligned --netG resnet_9blocks --direction AtoB --super_epochs 50 --super_epoch_start 0 --super_mode aligned --super_start 1 --name paired_gan_100 --no_dropout --n_epochs 50

# %% [markdown]
# ## Testing

# %% [markdown]
# #### 0% paired dataset

# %%
# %run test.py --dataroot ./datasets/t12t2_brain/0 --results_dir results/t12t2_brain/0 --model cycle_gan --dataset_mode single --netG resnet_9blocks --direction AtoB --name unpaired_gan --num_test 500 --no_dropout

# %% [markdown]
# #### 25% paired dataset

# %%
# %run test.py --dataroot ./datasets/t12t2_brain/0.25 --results_dir results/t12t2_brain/0.25 --model cycle_gan --dataset_mode single --netG resnet_9blocks --direction AtoB --name paired_gan_25 --num_test 500 --no_dropout

# %% [markdown]
# #### 50% paired dataset

# %%
# %run test.py --dataroot ./datasets/t12t2_brain/0.5 --results_dir results/t12t2_brain/0.5 --model cycle_gan --dataset_mode single --netG resnet_9blocks --direction AtoB --name paired_gan_50 --num_test 500 --no_dropout

# %% [markdown]
# #### 75% paired dataset

# %%
# %run test.py --dataroot ./datasets/t12t2_brain/0.75 --results_dir results/t12t2_brain/0.75 --model cycle_gan --dataset_mode single --netG resnet_9blocks --direction AtoB --name paired_gan_75 --num_test 500 --no_dropout

# %% [markdown]
# #### 100% paired dataset

# %%
# %run test.py --dataroot ./datasets/t12t2_brain/1 --results_dir results/t12t2_brain/1 --model cycle_gan --dataset_mode single --netG resnet_9blocks --direction AtoB --name paired_gan_100 --num_test 500 --no_dropout

# %% [markdown]
# ## Evaluation

# %% [markdown]
# #### 0% paired dataset

# %%
# No adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain/0

# %%
# Adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain_adv/0

# %% [markdown]
# #### 25% paired dataset

# %%
# No adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain/0.25

# %%
# Adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain_adv/0.25

# %% [markdown]
# #### 50% paired dataset

# %%
# No adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain/0.5

# %%
# Adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain_adv/0.5

# %% [markdown]
# #### 75% paired dataset

# %%
# No adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain/0.75

# %%
# Adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain_adv/0.75

# %% [markdown]
# #### 100% paired dataset

# %%
# No adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain/1

# %%
# Adversarial cycle consistency loss
# %run evaluation/FID_densenet121.py --base_path results/t12t2_brain_adv/1
